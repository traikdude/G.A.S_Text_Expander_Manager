# %% [markdown]
# <a href="https://colab.research.google.com/github/traikdude/G.A.S_Text_Expander_Manager/blob/master/notebooks/MLCategorizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧙🏾‍♂️ MLCategorizer.py - Colab Edition
# Run this notebook to execute the script directly from your Google Drive/Sheet integration.

# %%
# 🚀 MOUNT GOOGLE DRIVE
from google.colab import drive
drive.mount('/content/drive')

# 📥 CLONE REPOSITORY
# !git clone https://github.com/traikdude/G.A.S_Text_Expander_Manager.git
# %cd G.A.S_Text_Expander_Manager/tools

# 📦 INSTALL DEPENDENCIES
# !pip install -r requirements.txt
# Out:
# Mounted at /content/drive
# Cloning into 'G.A.S_Text_Expander_Manager'...
# remote: Enumerating objects: 496, done.
# remote: Counting objects: 100% (270/270), done.
# remote: Compressing objects: 100% (193/193), done.
# remote: Total 496 (delta 146), reused 193 (delta 72), pack-reused 226 (from 1)
# Receiving objects: 100% (496/496), 404.62 KiB | 10.94 MiB/s, done.
# Resolving deltas: 100% (275/275), done.
# /content/G.A.S_Text_Expander_Manager/tools
# ...

# %%
# 🏃‍♂️ RUN MLCATEGORIZER.PY
# !python MLCategorizer.py
# Out:
# ...
# Environment Detected: Local Python
# Base Path: /content/G.A.S_Text_Expander_Manager/tools
# Backup Path: /root/TextExpanderBackups
# Python: 3.12.12
# ...
#
# 📦 Installing packages: google-auth scikit-learn
# ✅ Packages ready: google-auth scikit-learn
# ✅ Libraries imported!
# 🔐 Authenticating with Google (Local)...
#
# ⚠️ No service account found. Starting OAuth flow...
# 💡 For automated usage, create a service account and save as credentials.json
#
# ❌ Authentication failed: [Errno 2] No such file or directory: '/root/.config/gspread/credentials.json'
#
# 📋 To fix this, you need to set up Google credentials:
#    1. Go to https://console.cloud.google.com/
#    2. Create a project and enable Sheets API + Drive API
#    3. Create a Service Account and download JSON key
#    4. Save as 'credentials.json' in this folder
#    5. Share your spreadsheet with the service account email
# ⚠️ Authentication failed: [Errno 2] No such file or directory: '/root/.config/gspread/credentials.json'
# ...
