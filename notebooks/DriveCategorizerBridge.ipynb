# %% [markdown]
# # 🧙🏾‍♂️ DriveCategorizerBridge.py - Colab Edition
# Run this notebook to execute the script directly from your Google Drive/Sheet integration.

# %%
# 🚀 MOUNT GOOGLE DRIVE
from google.colab import drive
drive.mount('/content/drive')

# 📥 CLONE REPOSITORY
# !git clone https://github.com/traikdude/G.A.S_Text_Expander_Manager.git
# %cd G.A.S_Text_Expander_Manager/tools

# 📦 INSTALL DEPENDENCIES
# !pip install -r requirements.txt

# %%
# 🏃‍♂️ RUN DRIVECATEGORIZERBRIDGE.PY
# !python DriveCategorizerBridge.py
